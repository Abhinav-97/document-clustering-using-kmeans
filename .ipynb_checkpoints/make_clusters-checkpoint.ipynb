# %%
import numpy as np
import pandas as pd
import nltk
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
from sklearn.externals import joblib

# %%
from sklearn.cluster import KMeans

# %%
stemmer = SnowballStemmer('english')

# %%
def tokenize_and_stem(text):
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    for token in tokens:
        if re.search('[a-zA-Z0-9]',token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

def tokenize_only(text):
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    for token in tokens:
        if re.search('[a-zA-Z0-9]',token):
            filtered_tokens.append(token)     
    return filtered_tokens

# %%
tokenize_and_stem(synopses_wiki[0])
# Out:
# ['list',
#  'of',
#  'to',
#  'kill',
#  'a',
#  'mockingbird',
#  'charact',
#  'the',
#  'stori',
#  'take',
#  'place',
#  'dure',
#  'three',
#  'year',
#  '1933–35',
#  'of',
#  'the',
#  'great',
#  'depress',
#  'in',
#  'the',
#  'fiction',
#  'tire',
#  'old',
#  'town',
#  'of',
#  'maycomb',
#  'alabama',
#  'the',
#  'seat',
#  'of',
#  'maycomb',
#  'counti',
#  'it',
#  'focus',
#  'on',
#  'six-year-old',
#  'jean',
#  'louis',
#  'finch',
#  'nicknam',
#  'scout',
#  'who',
#  'live',
#  'with',
#  'her',
#  'older',
#  'brother',
#  'jeremi',
#  'nicknam',
#  'jem',
#  'and',
#  'their',
#  'widow',
#  'father',
#  'atticus',
#  'a',
#  'middle-ag',
#  'lawyer',
#  'jem',
#  'and',
#  'scout',
#  'befriend',
#  'a',
#  'boy',
#  'name',
#  'dill',
#  'who',
#  'visit',
#  'maycomb',
#  'to',
#  'stay',
#  'with',
#  'his',
#  'aunt',
#  'each',
#  'summer',
#  'the',
#  'three',
#  'children',
#  'are',
#  'terrifi',
#  'yet',
#  'fascin',
#  'by',
#  'their',
#  'neighbor',
#  'the',
#  'reclus',
#  'arthur',
#  'boo',
#  'radley',
#  'the',
#  'adult',
#  'of',
#  'maycomb',
#  'are',
#  'hesit',
#  'to',
#  'talk',
#  'about',
#  'boo',
#  'and',
#  'few',
#  'of',
#  'them',
#  'have',
#  'seen',
#  'him',
#  'for',
#  'mani',
#  'year',
#  'the',
#  'children',
#  'feed',
#  'one',
#  'anoth',
#  'imagin',
#  'with',
#  'rumor',
#  'about',
#  'his',
#  'appear',
#  'and',
#  'reason',
#  'for',
#  'remain',
#  'hidden',
#  'and',
#  'they',
#  'fantas',
#  'about',
#  'how',
#  'to',
#  'get',
#  'him',
#  'out',
#  'of',
#  'his',
#  'hous',
#  'after',
#  'two',
#  'summer',
#  'of',
#  'friendship',
#  'with',
#  'dill',
#  'scout',
#  'and',
#  'jem',
#  'find',
#  'that',
#  'someon',
#  'leav',
#  'them',
#  'small',
#  'gift',
#  'in',
#  'a',
#  'tree',
#  'outsid',
#  'the',
#  'radley',
#  'place',
#  'sever',
#  'time',
#  'the',
#  'mysteri',
#  'boo',
#  'make',
#  'gestur',
#  'of',
#  'affect',
#  'to',
#  'the',
#  'children',
#  'but',
#  'to',
#  'their',
#  'disappoint',
#  'he',
#  'never',
#  'appear',
#  'in',
#  'person',
#  'great',
#  'depress',
#  'reclus',
#  'judg',
#  'taylor',
#  'appoint',
#  'atticus',
#  'to',
#  'defend',
#  'tom',
#  'robinson',
#  'a',
#  'black',
#  'man',
#  'who',
#  'has',
#  'been',
#  'accus',
#  'of',
#  'rape',
#  'a',
#  'young',
#  'white',
#  'woman',
#  'mayella',
#  'ewel',
#  'although',
#  'mani',
#  'of',
#  'maycomb',
#  'citizen',
#  'disapprov',
#  'atticus',
#  'agre',
#  'to',
#  'defend',
#  'tom',
#  'to',
#  'the',
#  'best',
#  'of',
#  'his',
#  'abil',
#  'other',
#  'children',
#  'taunt',
#  'jem',
#  'and',
#  'scout',
#  'for',
#  'atticuss',
#  'action',
#  'call',
#  'him',
#  'a',
#  'nigger-lov',
#  'scout',
#  'is',
#  'tempt',
#  'to',
#  'stand',
#  'up',
#  'for',
#  'her',
#  'father',
#  'honor',
#  'by',
#  'fight',
#  'even',
#  'though',
#  'he',
#  'has',
#  'told',
#  'her',
#  'not',
#  'to',
#  'atticus',
#  'face',
#  'a',
#  'group',
#  'of',
#  'men',
#  'intent',
#  'on',
#  'lynch',
#  'tom',
#  'this',
#  'danger',
#  'is',
#  'avert',
#  'when',
#  'scout',
#  'jem',
#  'and',
#  'dill',
#  'shame',
#  'the',
#  'mob',
#  'into',
#  'dispers',
#  'by',
#  'forc',
#  'them',
#  'to',
#  'view',
#  'the',
#  'situat',
#  'from',
#  'atticus',
#  'and',
#  'tom',
#  'perspect',
#  'nigger',
#  'atticus',
#  'doe',
#  'not',
#  'want',
#  'jem',
#  'and',
#  'scout',
#  'to',
#  'be',
#  'present',
#  'at',
#  'tom',
#  'robinson',
#  'trial',
#  'no',
#  'seat',
#  'is',
#  'avail',
#  'on',
#  'the',
#  'main',
#  'floor',
#  'so',
#  'by',
#  'invit',
#  'of',
#  'the',
#  'rev',
#  'syke',
#  'jem',
#  'scout',
#  'and',
#  'dill',
#  'watch',
#  'from',
#  'the',
#  'color',
#  'balconi',
#  'atticus',
#  'establish',
#  'that',
#  'the',
#  'accusers—mayella',
#  'and',
#  'her',
#  'father',
#  'bob',
#  'ewel',
#  'the',
#  'town',
#  'drunk—ar',
#  'lie',
#  'it',
#  'also',
#  'becom',
#  'clear',
#  'that',
#  'the',
#  'friendless',
#  'mayella',
#  'made',
#  'sexual',
#  'advanc',
#  'toward',
#  'tom',
#  'and',
#  'that',
#  'her',
#  'father',
#  'caught',
#  'her',
#  'and',
#  'beat',
#  'her',
#  'despit',
#  'signific',
#  'evid',
#  'of',
#  'tom',
#  'innoc',
#  'the',
#  'juri',
#  'convict',
#  'him',
#  'jem',
#  'faith',
#  'in',
#  'justic',
#  'becom',
#  'bad',
#  'shaken',
#  'as',
#  'is',
#  'atticus',
#  'when',
#  'the',
#  'hapless',
#  'tom',
#  'is',
#  'shot',
#  'and',
#  'kill',
#  'while',
#  'tri',
#  'to',
#  'escap',
#  'from',
#  'prison',
#  'color',
#  'balconi',
#  'town',
#  'drunk',
#  'despit',
#  'tom',
#  'convict',
#  'bob',
#  'ewel',
#  'is',
#  'humili',
#  'by',
#  'the',
#  'event',
#  'of',
#  'the',
#  'trial',
#  'atticus',
#  'explain',
#  'that',
#  'he',
#  'destroy',
#  'last',
#  'shred',
#  'of',
#  'credibl',
#  'at',
#  'that',
#  'trial',
#  'ewel',
#  'vow',
#  'reveng',
#  'spit',
#  'in',
#  'atticus',
#  'face',
#  'tri',
#  'to',
#  'break',
#  'into',
#  'the',
#  'judg',
#  'hous',
#  'and',
#  'menac',
#  'tom',
#  'robinson',
#  'widow',
#  'final',
#  'he',
#  'attack',
#  'the',
#  'defenseless',
#  'jem',
#  'and',
#  'scout',
#  'while',
#  'they',
#  'walk',
#  'home',
#  'on',
#  'a',
#  'dark',
#  'night',
#  'after',
#  'the',
#  'school',
#  'halloween',
#  'pageant',
#  'jem',
#  'suffer',
#  'a',
#  'broken',
#  'arm',
#  'in',
#  'the',
#  'struggl',
#  'but',
#  'amid',
#  'the',
#  'confus',
#  'someon',
#  'come',
#  'to',
#  'the',
#  'children',
#  'rescu',
#  'the',
#  'mysteri',
#  'man',
#  'carri',
#  'jem',
#  'home',
#  'where',
#  'scout',
#  'realiz',
#  'that',
#  'he',
#  'is',
#  'boo',
#  'radley',
#  'halloween',
#  'sheriff',
#  'tate',
#  'arriv',
#  'and',
#  'discov',
#  'that',
#  'bob',
#  'ewel',
#  'has',
#  'die',
#  'dure',
#  'the',
#  'fight',
#  'the',
#  'sheriff',
#  'argu',
#  'with',
#  'atticus',
#  'about',
#  'the',
#  'prudenc',
#  'and',
#  'ethic',
#  'of',
#  'charg',
#  'jem',
#  'whom',
#  'atticus',
#  'believ',
#  'to',
#  'be',
#  'respons',
#  'or',
#  'boo',
#  'whom',
#  'tate',
#  'believ',
#  'to',
#  'be',
#  'respons',
#  'atticus',
#  'eventu',
#  'accept',
#  'the',
#  'sheriff',
#  'stori',
#  'that',
#  'ewel',
#  'simpli',
#  'fell',
#  'on',
#  'his',
#  'own',
#  'knife',
#  'boo',
#  'ask',
#  'scout',
#  'to',
#  'walk',
#  'him',
#  'home',
#  'and',
#  'after',
#  'she',
#  'say',
#  'goodby',
#  'to',
#  'him',
#  'at',
#  'his',
#  'front',
#  'door',
#  'he',
#  'disappear',
#  'again',
#  'while',
#  'stand',
#  'on',
#  'the',
#  'radley',
#  'porch',
#  'scout',
#  'imagin',
#  'life',
#  'from',
#  'boo',
#  'perspect',
#  'and',
#  'regret',
#  'that',
#  'they',
#  'had',
#  'never',
#  'repaid',
#  'him',
#  'for',
#  'the',
#  'gift',
#  'he',
#  'had',
#  'given',
#  'them',
#  'scout',
#  'then',
#  'goe',
#  'back',
#  'home',
#  'to',
#  'atticus',
#  'and',
#  'stay',
#  'up',
#  'with',
#  'him',
#  'for',
#  'a',
#  'while',
#  'in',
#  'jem',
#  'room',
#  'soon',
#  'atticus',
#  'take',
#  'her',
#  'to',
#  'bed',
#  'and',
#  'tuck',
#  'her',
#  'in',
#  'befor',
#  'leav',
#  'to',
#  'go',
#  'back',
#  'to',
#  'jem']

# %%
synopses_wiki = []
synopses_wiki = open('wiki_summaries2.txt',encoding='utf-8').read().split('\nBREAK\n')

# %%
book_names = open('book_names.txt').read().split('\n')

# %%
book_names
# Out:
# ['To Kill a Mockingbird',
#  '1984',
#  'The Lord of the Rings (The Lord of the Rings, #1-3)',
#  'The Catcher in the Rye',
#  'The Great Gatsby',
#  'The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1)',
#  'Lord of the Flies',
#  'Animal Farm',
#  'Catch-22 (Catch-22, #1)',
#  'The Grapes of Wrath',
#  'Gone with the Wind',
#  'Slaughterhouse-Five',
#  'Lolita',
#  "One Flew Over the Cuckoo's Nest",
#  'A Clockwork Orange',
#  "Are You There God? It's Me, Margaret",
#  'Watchmen',
#  'Never Let Me Go',
#  'Atonement',
#  'Things Fall Apart (The African Trilogy, #1)',
#  'Beloved',
#  'Invisible Man',
#  'Mrs. Dalloway',
#  'The Sun Also Rises',
#  'On the Road',
#  'Possession',
#  'The Big Sleep (Philip Marlowe, #1)',
#  'A Passage to India',
#  'I, Claudius (Claudius, #1)',
#  'Their Eyes Were Watching God',
#  'The Sound and the Fury',
#  "All the King's Men",
#  'The Blind Assassin',
#  'Native Son',
#  'To the Lighthouse',
#  'Ragtime',
#  "The French Lieutenant's Woman",
#  'The Heart is a Lonely Hunter',
#  'Light in August',
#  'Naked Lunch',
#  'The Spy Who Came In from the Cold',
#  'Blood Meridian, or the Evening Redness in the West',
#  'White Noise',
#  'Infinite Jest',
#  'Snow Crash',
#  'Revolutionary Road',
#  'Brideshead Revisited: The Sacred and Profane Memories of Captain Charles Ryder',
#  "Midnight's Children",
#  'The Prime of Miss Jean Brodie',
#  'Death Comes for the Archbishop',
#  'The Bridge of San Luis Rey',
#  'Neuromancer (Sprawl, #1)',
#  'American Pastoral (The American Trilogy, #1)',
#  'The Corrections',
#  'The Power and the Glory',
#  'The Crying of Lot 49',
#  "Portnoy's Complaint",
#  'Wide Sargasso Sea',
#  "Gravity's Rainbow",
#  'Red Harvest',
#  'Rabbit, Run (Rabbit Angstrom #1)',
#  'White Teeth',
#  'Under the Volcano',
#  'The Painted Bird',
#  'Go Tell It on the Mountain',
#  'A House for Mr Biswas',
#  'Play It as It Lays',
#  'Lucky Jim',
#  'Ubik',
#  'The Golden Notebook',
#  'The Heart of the Matter',
#  'Pale Fire',
#  'The Moviegoer',
#  'The Confessions of Nat Turner',
#  'Tropic of Cancer',
#  'Appointment in Samarra',
#  'Money',
#  'Deliverance',
#  'The Day of the Locust',
#  'Housekeeping',
#  'The Man Who Loved Children',
#  'The Sot-Weed Factor',
#  'The Adventures of Augie March',
#  'Herzog',
#  'At Swim-Two-Birds',
#  'Call It Sleep',
#  'The Sheltering Sky',
#  'A Handful of Dust',
#  'The Sportswriter',
#  'The Berlin Stories: The Last of Mr Norris/Goodbye to Berlin',
dill watch from the colored balcony. Atticus establishes that the accusers—Mayella and her father, Bob Ewell, the town drunk—are lying. It also becomes clear that the friendless Mayella made sexual advances toward Tom, and that her father caught her and beat her. Despite significant evidence of Toms innocence, the jury convicts him. Jems faith in justice becomes badly shaken, as is Atticus, when the hapless Tom is shot and killed while trying to escape from prison. colored balcony town drunk Despite Toms conviction, Bob Ewell is humiliated by the events of the trial, Atticus explaining that he destroyed last shred of credibility at that trial. Ewell vows revenge, spitting in Atticus face, trying to break into the judges house, and menacing Tom Robinsons widow. Finally, he attacks the defenseless Jem and Scout while they walk home on a dark night after the school Halloween pageant. Jem suffers a broken arm in the struggle, but amid the confusion someone comes to the childrens rescue. The mysterious man carries Jem home, where Scout realizes that he is Boo Radley. Halloween Sheriff Tate arrives and discovers that Bob Ewell has died during the fight. The sheriff argues with Atticus about the prudence and ethics of charging Jem (whom Atticus believes to be responsible) or Boo (whom Tate believes to be responsible). Atticus eventually accepts the sheriffs story that Ewell simply fell on his own knife. Boo asks Scout to walk him home, and after she says goodbye to him at his front door he disappears again. While standing on the Radley porch, Scout imagines life from Boos perspective, and regrets that they had never repaid him for the gifts he had given them. Scout then goes back home to Atticus and stays up with him for a while in Jems room. Soon Atticus takes her to bed and tucks her in, before leaving to go back to Jem. '

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in synopses_wiki:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
len(totalvocab_stemmed)
# Out:
# 79712

# %%
vocab_data = pd.DataFrame({'words':totalvocab_tokenized }, index = totalvocab_stemmed)

# %%
vocab_data
# Out:
#                    words
# list                list
# of                    of
# to                    to
# kill                kill
# a                      a
# mockingbird  mockingbird
# charact       characters
# the                  the
# stori              story
# take               takes
# place              place
# dure              during
# three              three
# year               years
# 1933–35          1933–35
# of                    of
# the                  the
# great              great
# depress       depression
# in                    in
# the                  the
# fiction        fictional
# tire               tired
# old                  old
# town                town
# of                    of
# maycomb          maycomb
# alabama          alabama
# the                  the
# seat                seat
# ...                  ...
# call               calls
# thoma             thomas
# and                  and
# anna                anna
# to                    to
# tell                tell
# them                them
# where              where
# portia            portia
# is                    is
# the                  the
# novel              novel
# end                 ends
# with                with
# thoma             thomas
# and                  and
# anna                anna
# send             sending
# their              their
# maid                maid
# matchett        matchett
# to                    to
# major              major
# brutt             brutts
# hotel              hotel
# in                    in
# order              order
# to                    to
# fetch              fetch
# portia            portia
#
# [79712 rows x 1 columns]

# %%
vocab_data.loc[vocab_data['words']=="depression"]
# Out:
#               words
# depress  depression
# depress  depression
# depress  depression
# depress  depression
# depress  depression
# depress  depression

# %%
tfidf_vec = TfidfVectorizer(max_df=0.75,min_df=0.15,
                            stop_words='english',
                            tokenizer=tokenize_and_stem,
                            use_idf=True,
                            ngram_range=(1,3))

# %%
# %time tfidf_mat = tfidf_vec.fit_transform(synopses_wiki)
# Out:
# Wall time: 20.6 s

# %%
tfidf_mat.shape
# Out:
# (100, 333)

# %%
kmeans = joblib.load('cluster1.pkl')

# %%
stemmer.stem('hotel\'s')
# Out:
# 'hotel'

# %%
tfidf_mat.shape
# Out:
# (100, 333)

# %%
kmeans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fbc693066d49> in <module>()
# ----> 1 kmeans
#
# NameError: name 'kmeans' is not defined

# %%
tfidf_vec?

# %%
document_terms = tfidf_vec.get_feature_names()

# %%
len(document_terms)
# Out:
# 333

# %%
num = 5
kmeans = KMeans(n_clusters=num)

# %time kmeans.fit(tfidf_mat)
# Out:
# Wall time: 1.66 s
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = kmeans.labels_.tolist()

# %%
clusters
# Out:
# [1,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  4,
#  3,
#  1,
#  2,
#  4,
#  1,
#  2,
#  0,
#  1,
#  3,
#  0,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  0,
#  1,
#  2,
#  3,
#  2,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  3,
#  1,
#  2,
#  1,
#  0,
#  2,
#  2,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  0,
#  4,
#  3,
#  1,
#  1,
#  0,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  3,
#  1,
#  2,
#  0,
#  2,
#  1,
#  3,
#  3,
#  0,
#  2,
#  1,
#  1,
#  1,
#  3,
#  3,
#  3,
#  2,
#  1,
#  4,
#  1,
#  0,
#  3,
#  2,
#  2]

# %%
books_data = {'book_names':book_names, 'synopsis':synopses_wiki, 'cluster':clusters}

# %%
book_dataframe = pd.DataFrame(books_data,index=[clusters], columns=['book_names','synopsis','cluster'])

# %%
book_dataframe
# Out:
#                                            book_names  \
# 1                               To Kill a Mockingbird
# 2                                                1984
# 1   The Lord of the Rings (The Lord of the Rings, ...
# 3                              The Catcher in the Rye
# 3                                    The Great Gatsby
# 1   The Lion, the Witch, and the Wardrobe (Chronic...
# 4                                   Lord of the Flies
# 2                                         Animal Farm
# 2                             Catch-22 (Catch-22, #1)
# 2                                 The Grapes of Wrath
# 1                                  Gone with the Wind
# 2                                 Slaughterhouse-Five
# 1                                              Lolita
# 2                     One Flew Over the Cuckoo's Nest
# 1                                  A Clockwork Orange
# 4                Are You There God? It's Me, Margaret
# 3                                            Watchmen
# 1                                     Never Let Me Go
# 2                                           Atonement
# 4         Things Fall Apart (The African Trilogy, #1)
# 1                                             Beloved
# 2                                       Invisible Man
# 0                                       Mrs. Dalloway
# 1                                  The Sun Also Rises
# 3                                         On the Road
# 0                                          Possession
# 1                  The Big Sleep (Philip Marlowe, #1)
# 1                                  A Passage to India
# 2                          I, Claudius (Claudius, #1)
# 1                        Their Eyes Were Watching God
# ..                                                ...
# 1                             The Heart of the Matter
# 2                                           Pale Fire
# 2                                       The Moviegoer
# 1                       The Confessions of Nat Turner
# 2                                    Tropic of Cancer
# 1                              Appointment in Samarra
# 3                                               Money
# 1                                         Deliverance
# 2                               The Day of the Locust
# 0                                        Housekeeping
# 2                          The Man Who Loved Children
# 1                                 The Sot-Weed Factor
# 3                       The Adventures of Augie March
# 3                                              Herzog
# 0                                   At Swim-Two-Birds
# 2                                       Call It Sleep
# 1                                  The Sheltering Sky
# 1                                   A Handful of Dust
# 1                                    The Sportswriter
# 3   The Berlin Stories: The Last of Mr Norris/Good...
# 3                               A Death in the Family
# 3                                    The Recognitions
# 2                                        Dog Soldiers
# 1                                       The Assistant
# 4                                              Loving
# 1                                       Under the Net
# 0   A Dance to the Music of Time: 1st Movement (A ...
# 3                                 An American Tragedy
# 2                                            Falconer
# 2                              The Death of the Heart
#
#                                              synopsis  cluster
# 1    List of To Kill a Mockingbird characters The ...        1
# 2    edit Winston Smith is a man who lives in Airs...        2
# 1    edit Many years ago, two Hobbits, Smeagol and...        1
# 3    edit Holden Caulfield, a teenager from New Yo...        3
# 3    edit The main events of the novel take place ...        3
# 1    edit too long excessively detailed help impro...        1
# 4    In the midst of a wartime evacuation, a Briti...        4
# 2    Old Major, the old boar on the Manor Farm, su...        2
# 2    edit The plotline follows the airmen of the 2...        2
# 2    edit The narrative begins just after Tom Joad...        2
# 1    edit Gone with the Wind takes place in the so...        1
# 2    edit The story is told in a nonlinear order, ...        2
# 1    edit edit The story starts with a fictional f...        1
# 2    edit The book is narrated by "Chief" Bromden,...        2
# 1    edit edit Alex is a 15-year-old living in nea...        1
# 4    edit Margaret Simon is just turning twelve wh...        4
# 3    edit In October 1985, New York City police ar...        3
# 1    edit The story begins with Kathy, who describ...        1
# 2    edit edit Briony Tallis, a 13-year-old Englis...        2
# 4    edit Part 1 The novels protagonist Okonkwo is...        4
# 1    edit The book is the story of Sethe and her d...        1
# 2    edit The narrator, an unnamed black man, begi...        2
# 0    edit Clarissa Dalloway goes around London in ...        0
# 1    edit On the surface, the novel is a love stor...        1
# 3    edit The two main characters of the book are ...        3
# 0    edit Obscure scholar Roland Michell, research...        0
# 1    edit Private investigator Philip Marlowe is c...        1
# 1    edit edit A young British schoolmistress, Ade...        1
# 2    edit Claudius was the fourth Emperor of Rome ...        2
# 1    edit The main character Janie Crawford, an Af...        1
# ..                                                ...      ...
# 1    edit Major Scobie lives in a colony in the We...        1
# 2    edit Shades poem digressively describes many ...        2
# 2    edit The Moviegoer tells the story of Binx Bo...        2
# 1    edit The time is November, 1831. African Amer...        1
# 2    edit Set in France (primarily Paris) during t...        2
# 1    edit The novel describes how, over the course...        1
# 3    edit Money tells the story of, and is narrate...        3
# 1    edit Narrated in the first person by one of t...        1
# 2    edit Tod Hackett is the novels protagonist. H...        2
# 0    edit Ruthie narrates the story of how she and...        0
# 2    Edit The novel tells the story of a highly dy...        2
# 1    edit The novel is a satirical epic of the col...        1
# 3    Edit The story describes Augie Marchs growth ...        3
# 3    edit Herzog is set in 1964 in the United Stat...        3
# 0    edit At Swim-Two-Birds presents itself as a f...        0
# 2    edit Call It Sleep is the story of a Galician...        2
# 1    edit Three Americans from New York arrive in ...        1
# 1    edit Tony Last is a country gentleman, living...        1
# 1   The Sportswriter by Richard Ford is an introsp...        1
# 3    edit The novel follows the movements of Willi...        3
# 3    edit Batman relieves Jason Todd of his duties...        3
# 3    edit The story loosely follows the life of Wy...        3
# 2   Dog Soldiers deals with the fall of the counte...        2
# 1    edit Morris Bober, the 60-year-old proprietor...        1
# 4   Loving is a 1945 novel by British writer Henry...        4
# 1    edit too long excessively detailed help impro...        1
# 0   The twelve volumes of A Dance to the Music of ...        0
# 3    edit Ambitious, but ill-educated, naïve, and ...        3
# 2   shes a stunner.Edinburgh, 1844. Eighteen-year-...        2
# 2    edit At the beginning of the novel, Portia mo...        2
#
# [100 rows x 3 columns]

# %%
book_dataframe['cluster'].value_counts()
# Out:
# 2    38
# 1    32
# 3    15
# 0     9
# 4     6
# Name: cluster, dtype: int64

# %%
document_terms
# Out:
# ['abandon',
#  'abl',
#  'accept',
#  'accompani',
#  'act',
#  'action',
#  'affair',
#  'age',
#  'agre',
#  'allow',
#  'alon',
#  'alway',
#  'american',
#  'ani',
#  'anoth',
#  'apart',
#  'appear',
#  'approach',
#  'arrang',
#  'arriv',
#  'ask',
#  'attack',
#  'attempt',
#  'attend',
#  'attract',
#  'author',
#  'away',
#  'bad',
#  'becaus',
#  'becom',
#  'befor',
#  'begin',
#  'believ',
#  'black',
#  'bodi',
#  'book',
#  'boy',
#  'break',
#  'bring',
#  'brother',
#  'build',
#  'burn',
#  'busi',
#  'buy',
#  'car',
#  'care',
#  'caus',
#  'chang',
#  'charact',
#  'child',
#  'childhood',
#  'children',
#  'citi',
#  'claim',
#  'clear',
#  'close',
#  'come',
#  'commit',
#  'complet',
#  'confront',
#  'continu',
#  'control',
#  'convers',
#  'convinc',
#  'creat',
#  'daughter',
#  'day',
#  'dead',
#  'deal',
#  'death',
#  'decid',
#  'demand',
#  'describ',
#  'despit',
#  'destroy',
#  'develop',
#  'die',
#  'differ',
#  'discov',
#  'discuss',
#  'doe',
#  'drink',
#  'drive',
#  'dure',
#  'earli',
#  'encount',
#  'end',
#  'engag',
#  'england',
#  'enter',
#  'escap',
#  'establish',
#  'event',
#  'eventu',
#  'experi',
#  'explain',
#  'face',
#  'fact',
#  'fail',
#  'fall',
#  'famili',
#  'father',
#  'fear',
#  'feel',
#  'fiction',
#  'fight',
#  'final',
#  'flee',
#  'follow',
#  'forc',
#  'form',
#  'free',
#  'frequent',
#  'friend',
#  'girl',
#  'god',
#  'goe',
#  'good',
#  'great',
#  'group',
#  'grow',
#  'hand',
#  'happen',
#  'head',
#  'hear',
#  'help',
#  'hide',
#  'high',
#  'histori',
#  'hold',
#  'home',
#  'hope',
#  'hospit',
#  'hotel',
#  'hous',
#  'howev',
#  'idea',
#  'ident',
#  'includ',
#  'increas',
#  'inform',
#  'initi',
#  'instead',
#  'introduc',
#  'invit',
#  'involv',
#  'job',
#  'join',
#  'journey',
#  'just',
#  'kill',
#  'kind',
#  'know',
#  'known',
#  'late',
#  'later',
#  'lead',
#  'learn',
#  'leav',
#  'led',
#  'left',
#  'life',
#  'like',
#  'littl',
#  'live',
#  'local',
#  'london',
#  'long',
#  'look',
#  'lose',
#  'lost',
#  'love',
#  'lover',
#  'main',
#  'make',
#  'man',
#  'mani',
#  'marri',
#  'marriag',
#  'mean',
#  'meanwhil',
#  'meet',
#  'member',
#  'men',
#  'mental',
#  'mind',
#  'miss',
#  'moment',
#  'money',
#  'morn',
#  'mother',
#  'mr.',
#  'murder',
#  'narrat',
#  'natur',
#  'near',
#  'need',
#  'new',
#  'new york',
#  'night',
#  'note',
#  'novel',
#  'observ',
#  'obsess',
#  'offer',
#  'offic',
#  'old',
#  'older',
#  'onc',
#  'onli',
#  'open',
#  'order',
#  'origin',
#  'parti',
#  'particular',
#  'pass',
#  'past',
#  'pay',
#  'peopl',
#  'person',
#  'place',
#  'plan',
#  'play',
#  'point',
#  'polic',
#  'polit',
#  'possibl',
#  'power',
#  'present',
#  'previous',
#  'prison',
#  'promis',
#  'prostitut',
#  'provid',
#  'rape',
#  'reach',
#  'read',
#  'realiz',
#  'receiv',
#  'refer',
#  'reflect',
#  'refus',
#  'relat',
#  'relationship',
#  'remain',
#  'remov',
#  'respons',
#  'result',
#  'return',
#  'reveal',
#  'room',
#  'run',
#  'save',
#  'say',
#  'scene',
#  'school',
#  'search',
#  'second',
#  'secret',
#  'send',
#  'sens',
#  'serv',
#  'set',
#  'sever',
#  'sexual',
#  'share',
#  'short',
#  'sinc',
#  'sister',
#  'situat',
#  'sleep',
#  'small',
#  'societi',
#  'son',
#  'soon',
#  'speak',
#  'spend',
#  'start',
#  'state',
#  'stay',
#  'stop',
#  'stori',
#  'street',
#  'strike',
#  'struggl',
#  'success',
#  'sudden',
#  'suffer',
#  'suggest',
#  'suicid',
#  'suspect',
#  'taken',
#  'talk',
#  'tell',
#  'thing',
#  'think',
#  'throw',
#  'time',
#  'togeth',
#  'told',
#  'town',
#  'travel',
#  'tri',
#  'trip',
#  'true',
#  'turn',
#  'understand',
#  'unit',
#  'use',
#  'veri',
#  'view',
#  'visit',
#  'wait',
#  'walk',
#  'wander',
#  'want',
#  'war',
#  'watch',
#  'way',
#  'wealthi',
#  'white',
#  'wife',
#  'wit',
#  'woman',
#  'women',
#  'word',
#  'work',
#  'world',
#  'world war',
#  'write',
#  'year',
#  'york',
#  'young']

# %%
kmeans.cluster_centers_.argsort()[:,::-1]
# Out:
# array([[201, 104, 316, ..., 191, 303, 259],
#        [130, 158, 248, ..., 194, 261,   1],
#        [100, 193, 201, ...,  64, 292,  42],
#        [198, 331, 197, ..., 317, 267,  91],
#        [ 36, 115, 110, ...,  81,  82, 166]], dtype=int64)

# %%
centroids = kmeans.cluster_centers_.argsort()[:,::-1]
for i in range(num):
    print("cluster %d words" %i)
    print()
    for ind in centroids[i,:8]:
        print(ind)
        print(document_terms[ind],end=' ')
#         print(' %s'%vocab_data[document_terms[ind]],end=",")
# Out:
# cluster 0 words
#
# 201
# novel 104
# fiction 316
# war 48
# charact 56
# come 281
# stori 32
# believ 328
# world war cluster 1 words
#
# 130
# home 158
# leav 248
# return 175
# man 19
# arriv 320
# white 321
# wife 293
# tell cluster 2 words
#
# 100
# famili 193
# narrat 201
# novel 281
# stori 278
# state 51
# children 161
# life 35
# book cluster 3 words
#
# 198
# new york 331
# york 197
# new 52
# citi 190
# mother 181
# meet 158
# leav 101
# father cluster 4 words
#
# 36
# boy 115
# god 110
# form 316
# war 171
# love 320
# white 29
# becom 327
# world
